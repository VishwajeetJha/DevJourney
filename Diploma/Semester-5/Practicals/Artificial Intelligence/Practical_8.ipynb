# %%
class TicTacToe:
    def __init__(self):
        self.board = [' ' for _ in range(9)]  # A list to hold the board state
        self.current_player = 'X'  # Starting player

    def print_board(self):
        # Print the current state of the board
        print(f"{self.board[0]} | {self.board[1]} | {self.board[2]}")
        print("---------")
        print(f"{self.board[3]} | {self.board[4]} | {self.board[5]}")
        print("---------")
        print(f"{self.board[6]} | {self.board[7]} | {self.board[8]}")

    def check_winner(self):
        # Winning combinations
        winning_combinations = [
            (0, 1, 2), (3, 4, 5), (6, 7, 8),  # Rows
            (0, 3, 6), (1, 4, 7), (2, 5, 8),  # Columns
            (0, 4, 8), (2, 4, 6)              # Diagonals
        ]

        for combo in winning_combinations:
            if self.board[combo[0]] == self.board[combo[1]] == self.board[combo[2]] != ' ':
                return self.board[combo[0]]

        return None

    def is_draw(self):
        return ' ' not in self.board

    def make_move(self, position):
        if self.board[position] == ' ':
            self.board[position] = self.current_player
            winner = self.check_winner()
            if winner:
                self.print_board()
                print(f"Player {winner} wins!")
                return True
            if self.is_draw():
                self.print_board()
                print("It's a draw!")
                return True
            self.current_player = 'O' if self.current_player == 'X' else 'X'
        else:
            print("Invalid move. Try again.")
        return False

    def play(self):
        while True:
            self.print_board()
            try:
                position = int(input(f"Player {self.current_player}, enter your move (0-8): "))
                if position < 0 or position > 8:
                    print("Invalid position. Enter a number between 0 and 8.")
                    continue
            except ValueError:
                print("Invalid input. Please enter a number.")
                continue

            if self.make_move(position):
                break


if __name__ == "__main__":
    game = TicTacToe()
    game.play()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# Player X, enter your move (0-8): 2
#   |   | X
# ---------
#   |   |
# ---------
#   |   |
# Player O, enter your move (0-8): 1
#   | O | X
# ---------
#   |   |
# ---------
#   |   |
# Player X, enter your move (0-8): 5
#   | O | X
# ---------
#   |   | X
# ---------
#   |   |
# Player O, enter your move (0-8): 4
#   | O | X
# ---------
#   | O | X
# ---------
#   |   |
# Player X, enter your move (0-8): 8
#   | O | X
# ---------
#   | O | X
# ---------
#   |   | X
# Player X wins!

# %%
class TicTacToe:
    def __init__(self):
        self.board = [' ' for _ in range(9)]  # A list to hold the board state
        self.current_player = 'X'  # Starting player

    def print_board(self):
        # Print the current state of the board
        print(f"{self.board[0]} | {self.board[1]} | {self.board[2]}  | 0 | 1 | 2")
        print("---------")
        print(f"{self.board[3]} | {self.board[4]} | {self.board[5]}  | 3 | 4 | 5")
        print("---------")
        print(f"{self.board[6]} | {self.board[7]} | {self.board[8]}  | 6 | 7 | 8")
        print()  # Add an empty line for better readability

    def check_winner(self):
        # Winning combinations
        winning_combinations = [
            (0, 1, 2), (3, 4, 5), (6, 7, 8),  # Rows
            (0, 3, 6), (1, 4, 7), (2, 5, 8),  # Columns
            (0, 4, 8), (2, 4, 6)              # Diagonals
        ]

        for combo in winning_combinations:
            if self.board[combo[0]] == self.board[combo[1]] == self.board[combo[2]] != ' ':
                return self.board[combo[0]]

        return None

    def is_draw(self):
        return ' ' not in self.board

    def make_move(self, position):
        if self.board[position] == ' ':
            self.board[position] = self.current_player
            winner = self.check_winner()
            if winner:
                self.print_board()
                print(f"Player {winner} wins!")
                return True
            if self.is_draw():
                self.print_board()
                print("It's a draw!")
                return True
            self.current_player = 'O' if self.current_player == 'X' else 'X'
        else:
            print("Invalid move. Try again.")
        return False

    def play(self):
        while True:
            self.print_board()
            try:
                position = int(input(f"Player {self.current_player}, enter your move (0-8): "))
                if position < 0 or position > 8:
                    print("Invalid position. Enter a number between 0 and 8.")
                    continue
            except ValueError:
                print("Invalid input. Please enter a number.")
                continue

            if self.make_move(position):
                break


if __name__ == "__main__":
    game = TicTacToe()
    game.play()
# Out:
#   |   |    | 0 | 1 | 2
# ---------
#   |   |    | 3 | 4 | 5
# ---------
#   |   |    | 6 | 7 | 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2868bb388f11> in <cell line: 65>()
#      65 if __name__ == "__main__":
#      66     game = TicTacToe()
# ---> 67     game.play()
#
# <ipython-input-2-2868bb388f11> in play(self)
#      51             self.print_board()
#      52             try:
# ---> 53                 position = int(input(f"Player {self.current_player}, enter your move (0-8): "))
#      54                 if position < 0 or position > 8:
#      55                     print("Invalid position. Enter a number between 0 and 8.")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
class TicTacToe:
    def __init__(self):
        self.board = [' ' for _ in range(9)]  # A list to hold the board state
        self.current_player = 'X'  # Starting player

    def print_board(self):
        # Print the current state of the board
        print(f"{self.board[0]} | {self.board[1]} | {self.board[2]}  | 0 | 1 | 2")
        print("---------")
        print(f"{self.board[3]} | {self.board[4]} | {self.board[5]}  | 3 | 4 | 5")
        print("---------")
        print(f"{self.board[6]} | {self.board[7]} | {self.board[8]}  | 6 | 7 | 8")
        print()  # Add an empty line for better readability

    def check_winner(self):
        # Winning combinations
        winning_combinations = [
            (0, 1, 2), (3, 4, 5), (6, 7, 8),  # Rows
            (0, 3, 6), (1, 4, 7), (2, 5, 8),  # Columns
            (0, 4, 8), (2, 4, 6)              # Diagonals
        ]

        for combo in winning_combinations:
            if self.board[combo[0]] == self.board[combo[1]] == self.board[combo[2]] != ' ':
                return self.board[combo[0]]

        return None

    def is_draw(self):
        return ' ' not in self.board

    def make_move(self, position):
        if 0 <= position < 9:  # Ensure position is within valid range
            if self.board[position] == ' ':
                self.board[position] = self.current_player
                winner = self.check_winner()
                if winner:
                    self.print_board()
                    print(f"Player {winner} wins!")
                    return True
                if self.is_draw():
                    self.print_board()
                    print("It's a draw!")
                    return True
                self.current_player = 'O' if self.current_player == 'X' else 'X'
            else:
                print("Invalid move. The position is already occupied. Try again.")
        else:
            print("Invalid move. Enter a number between 0 and 8.")
        return False

    def play(self):
        while True:
            self.print_board()
            try:
                position = int(input(f"Player {self.current_player}, enter your move (0-8): "))
                if self.make_move(position):
                    break
            except ValueError:
                print("Invalid input. Please enter a number.")

if __name__ == "__main__":
    game = TicTacToe()
    game.play()
# Out:
#   |   |    | 0 | 1 | 2
# ---------
#   |   |    | 3 | 4 | 5
# ---------
#   |   |    | 6 | 7 | 8
#
# Player X, enter your move (0-8): 9
# Invalid move. Enter a number between 0 and 8.
#   |   |    | 0 | 1 | 2
# ---------
#   |   |    | 3 | 4 | 5
# ---------
#   |   |    | 6 | 7 | 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-84f4c3b614db> in <cell line: 62>()
#      62 if __name__ == "__main__":
#      63     game = TicTacToe()
# ---> 64     game.play()
#
# <ipython-input-3-84f4c3b614db> in play(self)
#      54             self.print_board()
#      55             try:
# ---> 56                 position = int(input(f"Player {self.current_player}, enter your move (0-8): "))
#      57                 if self.make_move(position):
#      58                     break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
class TicTacToe:
    def __init__(self):
        self.board = [' ' for _ in range(9)]  # A list to hold the board state
        self.current_player = None  # Will be set during symbol selection
        self.player_symbols = ['X', 'O']  # Default symbols

    def select_symbols(self):
        while True:
            player_x = input("Player 1, choose your symbol (X/O): ").upper()
            if player_x in self.player_symbols:
                player_o = 'O' if player_x == 'X' else 'X'
                self.current_player = player_x
                print(f"Player 1 is {player_x}, Player 2 is {player_o}.")
                return player_x, player_o
            else:
                print("Invalid symbol. Please choose either 'X' or 'O'.")

    def print_board(self):
        # Print the current state of the board
        print(f"{self.board[0]} | {self.board[1]} | {self.board[2]}  | 0 | 1 | 2")
        print("---------")
        print(f"{self.board[3]} | {self.board[4]} | {self.board[5]}  | 3 | 4 | 5")
        print("---------")
        print(f"{self.board[6]} | {self.board[7]} | {self.board[8]}  | 6 | 7 | 8")
        print()  # Add an empty line for better readability

    def check_winner(self):
        # Winning combinations
        winning_combinations = [
            (0, 1, 2), (3, 4, 5), (6, 7, 8),  # Rows
            (0, 3, 6), (1, 4, 7), (2, 5, 8),  # Columns
            (0, 4, 8), (2, 4, 6)              # Diagonals
        ]

        for combo in winning_combinations:
            if self.board[combo[0]] == self.board[combo[1]] == self.board[combo[2]] != ' ':
                return self.board[combo[0]]

        return None

    def is_draw(self):
        return ' ' not in self.board

    def make_move(self, position):
        if 0 <= position < 9:  # Ensure position is within valid range
            if self.board[position] == ' ':
                self.board[position] = self.current_player
                winner = self.check_winner()
                if winner:
                    self.print_board()
                    print(f"Player {winner} wins!")
                    return True
                if self.is_draw():
                    self.print_board()
                    print("It's a draw!")
                    return True
                self.current_player = 'O' if self.current_player == 'X' else 'X'
            else:
                print("Invalid move. The position is already occupied. Try again.")
        else:
            print("Invalid move. Enter a number between 0 and 8.")
        return False

    def play(self):
        player_x, player_o = self.select_symbols()
        self.current_player = player_x  # Set starting player

        while True:
            self.print_board()
            try:
                position = int(input(f"Player {self.current_player}, enter your move (0-8): "))
                if self.make_move(position):
                    break
            except ValueError:
                print("Invalid input. Please enter a number.")

if __name__ == "__main__":
    game = TicTacToe()
    game.play()
# Out:
# Player 1 is O, Player 2 is X.
#   |   |    | 0 | 1 | 2
# ---------
#   |   |    | 3 | 4 | 5
# ---------
#   |   |    | 6 | 7 | 8
